# %%
path = '../datasets/'

from keras.utils.np_utils import to_categorical

import numpy as np
import tensorflow as tf
import tqdm
from sklearn.model_selection import train_test_split
from os_elmOTENIM import OS_ELM
import pandas as pd


from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.metrics import confusion_matrix
import seaborn as sns

from timeit import default_timer as timer

# %%
def Otenim(n_input_nodes,n_hidden_nodes,n_output_nodes,X,y,f):
    
    os_elm = OS_ELM(
        n_input_nodes=n_input_nodes,
        n_hidden_nodes=n_hidden_nodes,
        n_output_nodes=n_output_nodes,
        loss='mean_squared_error',
        activation=f,
    )
    
    n_classes = n_output_nodes
    x_train, x_test, t_train, t_test = train_test_split(X, y, test_size=0.3, random_state=123)
    
    border = int(1.2 * n_hidden_nodes)
    x_train_init = x_train[:border]
    x_train_seq = x_train[border:]
    t_train_init = t_train[:border]
    t_train_seq = t_train[border:]
    
    start = timer ()
    os_elm.init_train(x_train_init, t_train_init)
    
    batch_size = 1
    
    for i in range(0, len(x_train_seq), batch_size):
        x_batch = x_train_seq[i:i+batch_size]
        t_batch = t_train_seq[i:i+batch_size]
        os_elm.seq_train(x_batch, t_batch)
    
    end = timer ()
    time = end - start
    #print("TIME", end - start)
    pred = os_elm.predict(x_test)
    y_ = softmax(pred)
    yy = []
    for i in y_:
        yy.append(np.argmax(i))
    tt = []
    for i in t_test:
        tt.append(np.argmax(i))
    #cm = confusion_matrix(tt, yy)
    #sns.heatmap(cm, annot=True)
    f1,a,p,r = metrics(tt,yy)
    
    return os_elm,time,f1,a,p,r

def softmax(a):
    c = np.max(a, axis=-1).reshape(-1, 1)
    exp_a = np.exp(a - c)
    sum_exp_a = np.sum(exp_a, axis=-1).reshape(-1, 1)
    return exp_a / sum_exp_a

def metrics(true,predicted):
    p = precision_score(true,predicted,average='macro',labels=np.unique(predicted))
    r = recall_score(true,predicted,average='macro')
    a = accuracy_score(true,predicted)
    f1 = f1_score(true,predicted,average='macro')

    return f1,a,p,r

# %%
n_input_nodes = 4 #CANTIDAD DE ATRIBUTOS
n_output_nodes = 3 #CANTIDAD DE CLASES


dataset = "iris.csv"
raw = pd.read_csv(path + dataset, header=0, skiprows=[1])
map = {'setosa':0,'versicolor':1,'virginica':2}
raw = raw.replace({'species':map})

y = raw["species"].to_numpy()
raw.drop(['species'],inplace=True,axis=1)



t = to_categorical(y, num_classes=3) 
X = raw.to_numpy()

min_max_scaler = MinMaxScaler()
X = min_max_scaler.fit_transform(X)


n_hidden_nodes = 25
tiempo = []
f1 = []
a = []
p = []
r = []

for i in range(50):
    tf.compat.v1.reset_default_graph()
    model,t_,f1_,a_,p_,r_ = Otenim(n_input_nodes,n_hidden_nodes,n_output_nodes,X,t,"sigmoid")
    tiempo.append(t_)
    f1.append(f1_)
    a.append(a_)
    p.append(p_)
    r.append(r_)
print("\nn_hidden_nodes =",n_hidden_nodes , "SIGMOID")
print("Tiempo:",np.mean(tiempo))
print("F1:",np.mean(f1))
print("A:",np.mean(a))
print("P:",np.mean(p))
print("R:",np.mean(r))




n_hidden_nodes = 50
tiempo = []
f1 = []
a = []
p = []
r = []

for i in range(50):
    tf.compat.v1.reset_default_graph()
    model,t_,f1_,a_,p_,r_ = Otenim(n_input_nodes,n_hidden_nodes,n_output_nodes,X,t,"sigmoid")
    tiempo.append(t_)
    f1.append(f1_)
    a.append(a_)
    p.append(p_)
    r.append(r_)
print("\nn_hidden_nodes =",n_hidden_nodes , "SIGMOID")
print("Tiempo:",np.mean(tiempo))
print("F1:",np.mean(f1))
print("A:",np.mean(a))
print("P:",np.mean(p))
print("R:",np.mean(r))



n_hidden_nodes = 100
tiempo = []
f1 = []
a = []
p = []
r = []

for i in range(50):
    tf.compat.v1.reset_default_graph()
    model,t_,f1_,a_,p_,r_ = Otenim(n_input_nodes,n_hidden_nodes,n_output_nodes,X,t,"sigmoid")
    tiempo.append(t_)
    f1.append(f1_)
    a.append(a_)
    p.append(p_)
    r.append(r_)
print("\nn_hidden_nodes =",n_hidden_nodes , "SIGMOID")
print("Tiempo:",np.mean(tiempo))
print("F1:",np.mean(f1))
print("A:",np.mean(a))
print("P:",np.mean(p))
print("R:",np.mean(r))


n_hidden_nodes = 25
tiempo = []
f1 = []
a = []
p = []
r = []

for i in range(50):
    tf.compat.v1.reset_default_graph()
    model,t_,f1_,a_,p_,r_ = Otenim(n_input_nodes,n_hidden_nodes,n_output_nodes,X,t,"relu")
    tiempo.append(t_)
    f1.append(f1_)
    a.append(a_)
    p.append(p_)
    r.append(r_)
print("\nn_hidden_nodes =",n_hidden_nodes , "RELU")
print("Tiempo:",np.mean(tiempo))
print("F1:",np.mean(f1))
print("A:",np.mean(a))
print("P:",np.mean(p))
print("R:",np.mean(r))



n_hidden_nodes = 50
tiempo = []
f1 = []
a = []
p = []
r = []

for i in range(50):
    tf.compat.v1.reset_default_graph()
    model,t_,f1_,a_,p_,r_ = Otenim(n_input_nodes,n_hidden_nodes,n_output_nodes,X,t,"relu")
    tiempo.append(t_)
    f1.append(f1_)
    a.append(a_)
    p.append(p_)
    r.append(r_)
print("\nn_hidden_nodes =",n_hidden_nodes , "RELU")
print("Tiempo:",np.mean(tiempo))
print("F1:",np.mean(f1))
print("A:",np.mean(a))
print("P:",np.mean(p))
print("R:",np.mean(r))


n_hidden_nodes = 100
tiempo = []
f1 = []
a = []
p = []
r = []

for i in range(50):
    tf.compat.v1.reset_default_graph()
    model,t_,f1_,a_,p_,r_ = Otenim(n_input_nodes,n_hidden_nodes,n_output_nodes,X,t,"relu")
    tiempo.append(t_)
    f1.append(f1_)
    a.append(a_)
    p.append(p_)
    r.append(r_)
print("\nn_hidden_nodes =",n_hidden_nodes , "RELU")
print("Tiempo:",np.mean(tiempo))
print("F1:",np.mean(f1))
print("A:",np.mean(a))
print("P:",np.mean(p))
print("R:",np.mean(r))
# Out:
# n_hidden_nodes = 25 SIGMOID
# Tiempo: 0.04101363599998422
# F1: 0.8466835370511842
# A: 0.8697777777777778
# P: 0.845698327815975
# R: 0.8494117647058823
#
# n_hidden_nodes = 50 SIGMOID
# Tiempo: 0.03317764600004011
# F1: 0.8473042398777693
# A: 0.8697777777777778
# P: 0.845668597742127
# R: 0.8507843137254902
#
# n_hidden_nodes = 100 SIGMOID
# Tiempo: 0.011843618000020796
# F1: 0.843938693659282
# A: 0.8666666666666667
# P: 0.8421724598930481
# R: 0.8477647058823529
#
# n_hidden_nodes = 25 RELU
# Tiempo: 0.04024912399997447
# F1: 0.9217478683092408
# A: 0.9324444444444444
# P: 0.9214715763539294
# R: 0.9283572984749456
#
# n_hidden_nodes = 50 RELU
# Tiempo: 0.03228418200003034
# F1: 0.9230151631788895
# A: 0.9337777777777778
# P: 0.9219587634587636
# R: 0.928392156862745
#
# n_hidden_nodes = 100 RELU
# Tiempo: 0.011761883999997735
# F1: 0.9241526595465421
# A: 0.9346666666666666
# P: 0.9222082166199813
# R: 0.9310980392156861
